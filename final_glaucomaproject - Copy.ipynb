# %%
import matplotlib.pyplot as plt  
import numpy as np
import os                        
import shutil                    
from tensorflow import keras
import seaborn as sns
import random
from keras.models import load_model
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
current_dir = os.getcwd()
print(current_dir)
# Out:
# C:\Users\rekha

# %%
dristhi_dir = r"C:\Users\rekha\Downloads\DRISHTI-GS"
train_glaucoma_dir = r"C:\Users\rekha\Downloads\DRISHTI-GS\Training\glaucoma"
train_normal_dir = r"C:\Users\rekha\Downloads\DRISHTI-GS\Training\normal"
test_glaucoma_dir = r"C:\Users\rekha\Downloads\DRISHTI-GS\Testing\glaucoma"
test_normal_dir =r"C:\Users\rekha\Downloads\DRISHTI-GS\Testing\normal"
dristhi_glaucoma_images = os.listdir(train_glaucoma_dir)+os.listdir(test_glaucoma_dir)
dristhi_normal_images = os.listdir(train_normal_dir)+os.listdir(test_normal_dir)

# Look at the number of samples in each dataset
print("Dristhi dataset contains :")
print(f"\t{len(dristhi_glaucoma_images)} images representing an eye with glaucoma")
print(f"\t{len(dristhi_normal_images)} images representing a normal eye")
# Out:
# Dristhi dataset contains :
# 	70 images representing an eye with glaucoma
# 	31 images representing a normal eye

# %%
print("Sample Dristhi glaucoma images:")
plt.subplots(figsize=(15, 10))
for i in range(1, 5):
    plt.subplot(1, 4, i)
    plt.imshow(load_img(f"{os.path.join(train_glaucoma_dir, dristhi_glaucoma_images[i - 1])}"))
plt.show()

print("\nSample Dristhi normal images:")
plt.subplots(figsize=(15, 10))
for i in range(1, 5):
    plt.subplot(1, 4, i)
    plt.imshow(load_img(f"{os.path.join(train_normal_dir, dristhi_normal_images[i - 1])}"))
plt.show()
# Out:
# Sample Dristhi glaucoma images:
# C:\Users\rekha\AppData\Local\Temp\ipykernel_13452\61996552.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 4, i)
# Sample Dristhi normal images:
# C:\Users\rekha\AppData\Local\Temp\ipykernel_13452\61996552.py:11: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 4, i)

# %%
rimOne_dir =r"C:\Users\rekha\Downloads\RIM-ONE_DL_images\partitioned_randomly"
train_glaucoma_dir =r"C:\Users\rekha\Downloads\RIM-ONE_DL_images\partitioned_randomly\training_set\glaucoma"
train_normal_dir = r"C:\Users\rekha\Downloads\RIM-ONE_DL_images\partitioned_randomly\training_set\normal"
test_glaucoma_dir = r"C:\Users\rekha\Downloads\RIM-ONE_DL_images\partitioned_randomly\test_set\glaucoma"
test_normal_dir = r"C:\Users\rekha\Downloads\RIM-ONE_DL_images\partitioned_randomly\test_set\normal"
rimOne_glaucoma_images = os.listdir(train_glaucoma_dir)+os.listdir(test_glaucoma_dir)
rimOne_normal_images = os.listdir(train_normal_dir)+os.listdir(test_normal_dir)

# Look at the number of samples in each dataset
print("Rim One dataset contains :")
print(f"\t{len(rimOne_glaucoma_images)} images representing an eye with glaucoma")
print(f"\t{len(rimOne_normal_images)} images representing a normal eye")
# Out:
# Rim One dataset contains :
# 	172 images representing an eye with glaucoma
# 	313 images representing a normal eye

# %%
print("Sample Rim-One glaucoma images:")
plt.subplots(figsize=(15, 10))
for i in range(1, 5):
    plt.subplot(1, 4, i)
    plt.imshow(load_img(f"{os.path.join(train_glaucoma_dir, rimOne_glaucoma_images[i - 1])}"))
plt.show()

print("\nSample Rim-One normal images:")
plt.subplots(figsize=(15, 10))
for i in range(1, 5):
    plt.subplot(1, 4, i)
    plt.imshow(load_img(f"{os.path.join(train_normal_dir, rimOne_normal_images[i - 1])}"))
plt.show()
# Out:
# Sample Rim-One glaucoma images:
# C:\Users\rekha\AppData\Local\Temp\ipykernel_13452\873921626.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 4, i)
# Sample Rim-One normal images:
# C:\Users\rekha\AppData\Local\Temp\ipykernel_13452\873921626.py:11: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 4, i)

# %%
acrima_dir = r"C:\Users\rekha\Downloads\ACRIMA\NOT PARTITIONED"
glaucoma_dir =r"C:\Users\rekha\Downloads\ACRIMA\NOT PARTITIONED\glaucoma"
normal_dir = r"C:\Users\rekha\Downloads\ACRIMA\NOT PARTITIONED\normal"
normal_images = os.listdir(normal_dir)
glaucoma_images = os.listdir(glaucoma_dir)

# Look at the number of samples in each dataset
print("Acrima dataset contains : ")
print(f"\t{len(glaucoma_images)} images representing an eye with glaucoma")
print(f"\t{len(normal_images)} images representing a normal eye")
# Out:
# Acrima dataset contains :
# 	396 images representing an eye with glaucoma
# 	309 images representing a normal eye

# %%
print("Sample glaucoma images:")
plt.subplots(figsize=(15, 10))
for i in range(1, 5):
    plt.subplot(1, 4, i)
    plt.imshow(load_img(f"{os.path.join(glaucoma_dir, glaucoma_images[i - 1])}"))
plt.show()

print("\nSample normal images:")
plt.subplots(figsize=(15, 10))
for i in range(1, 5):
    plt.subplot(1, 4, i)
    plt.imshow(load_img(f"{os.path.join(normal_dir, normal_images[i - 1])}"))
plt.show()
# Out:
# Sample glaucoma images:
# C:\Users\rekha\AppData\Local\Temp\ipykernel_13452\2410014847.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 4, i)
# Sample normal images:
# C:\Users\rekha\AppData\Local\Temp\ipykernel_13452\2410014847.py:11: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 4, i)

# %%
origa_dir = r"C:\Users\rekha\Downloads\ORIGA"
glaucoma_dir =r"C:\Users\rekha\Downloads\ORIGA\Training\glaucoma"
normal_dir = r"C:\Users\rekha\Downloads\ORIGA\Training\normal"
normal_images = os.listdir(normal_dir)
glaucoma_images = os.listdir(glaucoma_dir)

# Look at the number of samples in each dataset
print("Acrima dataset contains : ")
print(f"\t{len(glaucoma_images)} images representing an eye with glaucoma")
print(f"\t{len(normal_images)} images representing a normal eye")
# Out:
# Acrima dataset contains :
# 	134 images representing an eye with glaucoma
# 	386 images representing a normal eye

# %%
print("Sample glaucoma images:")
plt.subplots(figsize=(15, 10))
for i in range(1, 5):
    plt.subplot(1, 4, i)
    plt.imshow(load_img(f"{os.path.join(glaucoma_dir, glaucoma_images[i - 1])}"))
plt.show()

print("\nSample normal images:")
plt.subplots(figsize=(15, 10))
for i in range(1, 5):
    plt.subplot(1, 4, i)
    plt.imshow(load_img(f"{os.path.join(normal_dir, normal_images[i - 1])}"))
plt.show()
# Out:
# Sample glaucoma images:
# C:\Users\rekha\AppData\Local\Temp\ipykernel_13452\2410014847.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 4, i)
# Sample normal images:
# C:\Users\rekha\AppData\Local\Temp\ipykernel_13452\2410014847.py:11: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 4, i)

# %%
import os
import shutil

# Create the destination directory for combined glaucoma and normal images
combine_path = r"C:\Users\rekha\Downloads\combineo"
os.mkdir(combine_path)

# Define paths for glaucoma images
g_path1 = r"C:\Users\rekha\Downloads\ACRIMA\NOT PARTITIONED\glaucoma"
g_path2 = r"C:\Users\rekha\Downloads\RIM-ONE_DL_images\partitioned_randomly\training_set\glaucoma"
g_path3 = r"C:\Users\rekha\Downloads\RIM-ONE_DL_images\partitioned_randomly\test_set\glaucoma"
g_path4 = r"C:\Users\rekha\Downloads\DRISHTI-GS\Training\glaucoma"
g_path5 = r"C:\Users\rekha\Downloads\DRISHTI-GS\Testing\glaucoma"
g_path6=r"C:\Users\rekha\Downloads\Train\Glaucoma_Positive"
g_path7=r"C:\Users\rekha\Downloads\ORIGA\Training\glaucoma"

g_dest = os.path.join(combine_path, "glaucoma")
os.mkdir(g_dest)

g_list = [g_path1, g_path2, g_path3, g_path4, g_path5,g_path6, g_path7]

# Copy all glaucoma images to the combined destination
for path in g_list:
    shutil.copytree(path, g_dest, dirs_exist_ok=True)

print(f"Total Glaucoma Images: {len(os.listdir(g_dest))}")

# Define paths for normal images
n_path1 =r"C:\Users\rekha\Downloads\ACRIMA\NOT PARTITIONED\normal"
n_path2 = r"C:\Users\rekha\Downloads\RIM-ONE_DL_images\partitioned_randomly\training_set\normal"
n_path3 = r"C:\Users\rekha\Downloads\RIM-ONE_DL_images\partitioned_randomly\test_set\normal"
n_path4 = r"C:\Users\rekha\Downloads\DRISHTI-GS\Training\normal"
n_path5 = r"C:\Users\rekha\Downloads\DRISHTI-GS\Testing\normal"
n_path6=r"C:\Users\rekha\Downloads\Train\Glaucoma_Negative"
n_path7=r"C:\Users\rekha\Downloads\ORIGA\Training\normal"

n_dest = os.path.join(combine_path, "normal")
os.mkdir(n_dest)

n_list = [ n_path1,n_path2, n_path3, n_path4, n_path5, n_path6, n_path7]

# Copy all normal images to the combined destination
for path in n_list:
    shutil.copytree(path, n_dest, dirs_exist_ok=True)

print(f"Total Normal Images: {len(os.listdir(n_dest))}")
# Out:
# Total Glaucoma Images: 777
# Total Normal Images: 1043

# %%
import os
import pathlib  # Import pathlib

base_dir = r"C:\Users\rekha\Downloads\combineo"
base_dir = pathlib.Path(base_dir)

glaucoma = [fn for fn in os.listdir(base_dir / "glaucoma")]
normal = [fn for fn in os.listdir(base_dir / "normal")]


data=[glaucoma,normal]
dataset_classes =['glaucoma','normal']

image_count = len(list(base_dir.glob('*/*.jpg')))+len(list(base_dir.glob('*/*.png')))
print(f'Total images: {image_count}')
print(f'Total number of classes: {len(dataset_classes)}')
count = 0
data_count = []
for x in dataset_classes:
  print(f'Total {x} images: {len(data[count])}')
  data_count.append(len(data[count]))
  count += 1

sns.set_style('darkgrid')
sns.barplot(x=dataset_classes, y=data_count)
plt.show()
# Out:
# Total images: 1820
# Total number of classes: 2
# Total glaucoma images: 777
# Total normal images: 1043

# %%
# !pip install split-folders 

import splitfolders
import pathlib

# Define dataset path
base_ds = r"C:\Users\rekha\Downloads\combineo"
base_ds = pathlib.Path(base_ds)

# Split dataset (80% train, 10% validation, 10% test)
splitfolders.ratio(base_ds, output=r"C:\Users\rekha\Downloads\glu_data", seed=1321, ratio=(.8, .1, .1), group_prefix=None, move=False)
# Out:
# Requirement already satisfied: split-folders in c:\users\rekha\anaconda3\lib\site-packages (0.5.1)
# Copying files: 1820 files [00:18, 99.02 files/s]

# %%
img_height=256
img_width=256

from tensorflow.keras.preprocessing.image import ImageDataGenerator
batch_size=32

# Create ImageDataGenerator for training, validation, and testing
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.15,
    zoom_range=0.15,
    horizontal_flip=True
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

# Load datasets
train_ds = train_datagen.flow_from_directory(
    r"C:\Users\rekha\Downloads\glu_data\train",
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

val_ds = val_test_datagen.flow_from_directory(
    r"C:\Users\rekha\Downloads\glu_data\val",
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

test_ds = val_test_datagen.flow_from_directory(
    r"C:\Users\rekha\Downloads\glu_data\test",  # Ensure test_dir is defined and points to the test folder
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 1455 images belonging to 2 classes.
# Found 181 images belonging to 2 classes.
# Found 184 images belonging to 2 classes.

# %% [markdown]
# # VGG16 Model

# %%
import os
import tensorflow as tf
import matplotlib.pyplot as plt

# Parameters
image_size = (256, 256)  # Resize images to this size
batch_size = 32  # Process images in batches
data_dir = r"C:\Users\rekha\Downloads\glu_data"  # Path to the dataset

# Load datasets using TensorFlow's image_dataset_from_directory
train_dataset = tf.keras.utils.image_dataset_from_directory(
    os.path.join(data_dir, "train"),
    image_size=image_size,
    batch_size=batch_size,
    label_mode='int',  # Labels are encoded as integers
)

val_dataset = tf.keras.utils.image_dataset_from_directory(
    os.path.join(data_dir, "val"),
    image_size=image_size,
    batch_size=batch_size,
    label_mode='int',
)

test_dataset = tf.keras.utils.image_dataset_from_directory(
    os.path.join(data_dir, "test"),
    image_size=image_size,
    batch_size=batch_size,
    label_mode='int',
)

# Get class names
class_names = train_dataset.class_names
print("Class names:", class_names)

plt.figure(figsize=(10, 5))
for images, labels in train_dataset.take(1):  
    for i in range(5):
        plt.subplot(1, 5, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))  # Convert image to displayable format
        plt.title(class_names[labels[i]])
        plt.axis("off")
plt.show()

# Prepare datasets for performance 
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_dataset = val_dataset.cache().prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.cache().prefetch(buffer_size=AUTOTUNE)

# Summary of datasets
print(f"Train dataset batches: {len(train_dataset)}")
print(f"Validation dataset batches: {len(val_dataset)}")
print(f"Test dataset batches: {len(test_dataset)}")
# Out:
# Found 1455 files belonging to 2 classes.
# Found 181 files belonging to 2 classes.
# Found 184 files belonging to 2 classes.
# Class names: ['glaucoma', 'normal']
# Train dataset batches: 46
# Validation dataset batches: 6
# Test dataset batches: 6

# %% [markdown]
# VGG16

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import os

# Load datasets using TensorFlow's `image_dataset_from_directory`
data_dir = r"C:\Users\rekha\Downloads\glu_data"
image_size = (256, 256)
batch_size = 64

train_ds = tf.keras.utils.image_dataset_from_directory(
    os.path.join(data_dir, "train"),
    image_size=image_size,
    batch_size=batch_size,
    label_mode='binary',  # For binary classification
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    os.path.join(data_dir, "val"),
    image_size=image_size,
    batch_size=batch_size,
    label_mode='binary',
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    os.path.join(data_dir, "test"),
    image_size=image_size,
    batch_size=batch_size,
    label_mode='binary',
)

# Prepare datasets for performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# Load pre-trained VGG16 model without the top layer
base_model = VGG16(weights="imagenet", include_top=False, input_shape=(256, 256, 3))

# Freeze base model layers
for layer in base_model.layers:
    layer.trainable = False

# Add custom layers on top of the VGG16 base model
model = Sequential([
    base_model,
    Flatten(),
    Dense(128, activation="relu"),
    Dropout(0.5),
    Dense(1, activation="sigmoid")  # For binary classification
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss="binary_crossentropy",
              metrics=["accuracy"])

# Train the model
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10
)

# Evaluate the model on the test dataset
test_loss, test_accuracy = model.evaluate(test_ds)
print(f"Test Accuracy: {test_accuracy:.2f}")

# Plot training history
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Found 1455 files belonging to 2 classes.
# Found 181 files belonging to 2 classes.
# Found 184 files belonging to 2 classes.
# Epoch 1/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 334s 14s/step - accuracy: 0.5859 - loss: 8.0592 - val_accuracy: 0.7514 - val_loss: 0.9671
# Epoch 2/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 320s 14s/step - accuracy: 0.7997 - loss: 0.5136 - val_accuracy: 0.7569 - val_loss: 0.4913
# Epoch 3/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 359s 16s/step - accuracy: 0.7777 - loss: 0.4247 - val_accuracy: 0.8066 - val_loss: 0.4498
# Epoch 4/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 368s 16s/step - accuracy: 0.7920 - loss: 0.3540 - val_accuracy: 0.7901 - val_loss: 0.4839
# Epoch 5/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 411s 18s/step - accuracy: 0.8579 - loss: 0.3049 - val_accuracy: 0.7845 - val_loss: 0.4637
# Epoch 6/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 334s 14s/step - accuracy: 0.8563 - loss: 0.2750 - val_accuracy: 0.8066 - val_loss: 0.4866
# Epoch 7/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 320s 14s/step - accuracy: 0.8748 - loss: 0.2444 - val_accuracy: 0.7901 - val_loss: 0.4497
# Epoch 8/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 310s 13s/step - accuracy: 0.8801 - loss: 0.2137 - val_accuracy: 0.8066 - val_loss: 0.5122
# Epoch 9/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 329s 14s/step - accuracy: 0.8943 - loss: 0.1895 - val_accuracy: 0.8011 - val_loss: 0.5904
# Epoch 10/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 351s 15s/step - accuracy: 0.9130 - loss: 0.1507 - val_accuracy: 0.8011 - val_loss: 0.5320
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 37s 12s/step - accuracy: 0.8419 - loss: 0.4193
# Test Accuracy: 0.85

# %% [markdown]
# # MobileNet

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks

# Data Preprocessing
train_dataset = tf.keras.utils.image_dataset_from_directory(
    r"C:\Users\rekha\Downloads\glu_data\train",  # Replace with the path to your training data
    image_size=(256, 256),
    batch_size=32,
    label_mode='categorical'  # For multi-class classification
)

val_dataset = tf.keras.utils.image_dataset_from_directory(
    r"C:\Users\rekha\Downloads\glu_data\val",  # Replace with the path to your validation data
    image_size=(256, 256),
    batch_size=32,
    label_mode='categorical'
)

# Normalize the data
normalization_layer = layers.Rescaling(1.0 / 255)
train_dataset = train_dataset.map(lambda x, y: (normalization_layer(x), y))
val_dataset = val_dataset.map(lambda x, y: (normalization_layer(x), y))

# Data Augmentation
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.4),
    layers.RandomZoom(0.4),
    layers.RandomContrast(0.3),
    layers.RandomBrightness(0.3),
    layers.RandomTranslation(0.3, 0.3),
    layers.GaussianNoise(0.1)  # Adding slight noise to help generalization
])
#train_dataset = train_dataset.map(lambda x, y: (data_augmentation(x, training=True), y))


# Model Architecture
base_model = tf.keras.applications.MobileNetV2(input_shape=(256, 256, 3),
                                               include_top=False,
                                               weights='imagenet')
base_model.trainable = False  # Freeze initial layers

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dropout(0.5),
    layers.Dense(2, activation='softmax')
])

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.001,
    decay_steps=10000,
    decay_rate=0.9
)
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

# Compile the Model
model.compile(
    optimizer=optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
#lr_schedule = callbacks.ReduceLROnPlateau(
 #   monitor='val_loss',
 #   factor=0.2,   patience=5,   min_lr=1e-6)


#model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])


# Remove `ReduceLROnPlateau`:
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=25,
    # No ReduceLROnPlateau
)

# Callbacks
#reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)


#early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Fit the Model
'''history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=100,
    callbacks=[reduce_lr]#, early_stopping]
)'''


# Evaluate the Model
test_loss, test_accuracy = model.evaluate(val_dataset)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Found 1455 files belonging to 2 classes.
# Found 181 files belonging to 2 classes.
# C:\Users\rekha\AppData\Local\Temp\ipykernel_16584\1273055590.py:38: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = tf.keras.applications.MobileNetV2(input_shape=(256, 256, 3),
# Epoch 1/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 763ms/step - accuracy: 0.5733 - loss: 0.9185 - val_accuracy: 0.7072 - val_loss: 0.5735
# Epoch 2/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 34s 717ms/step - accuracy: 0.6832 - loss: 0.6675 - val_accuracy: 0.7680 - val_loss: 0.4759
# Epoch 3/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 32s 660ms/step - accuracy: 0.7335 - loss: 0.5834 - val_accuracy: 0.7735 - val_loss: 0.4632
# Epoch 4/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 644ms/step - accuracy: 0.7370 - loss: 0.5460 - val_accuracy: 0.7845 - val_loss: 0.4641
# Epoch 5/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 651ms/step - accuracy: 0.7537 - loss: 0.5324 - val_accuracy: 0.7845 - val_loss: 0.4803
# Epoch 6/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 647ms/step - accuracy: 0.7653 - loss: 0.5259 - val_accuracy: 0.7790 - val_loss: 0.4664
# Epoch 7/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 646ms/step - accuracy: 0.7959 - loss: 0.4860 - val_accuracy: 0.7901 - val_loss: 0.4359
# Epoch 8/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 647ms/step - accuracy: 0.7856 - loss: 0.4566 - val_accuracy: 0.8066 - val_loss: 0.4099
# Epoch 9/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 649ms/step - accuracy: 0.7873 - loss: 0.4589 - val_accuracy: 0.7901 - val_loss: 0.4340
# Epoch 10/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 647ms/step - accuracy: 0.8045 - loss: 0.4535 - val_accuracy: 0.7790 - val_loss: 0.4447
# Epoch 11/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 646ms/step - accuracy: 0.7936 - loss: 0.4322 - val_accuracy: 0.7790 - val_loss: 0.4330
# Epoch 12/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 639ms/step - accuracy: 0.7862 - loss: 0.4595 - val_accuracy: 0.8011 - val_loss: 0.4210
# Epoch 13/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 643ms/step - accuracy: 0.7906 - loss: 0.4483 - val_accuracy: 0.8011 - val_loss: 0.4122
# Epoch 14/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 32s 676ms/step - accuracy: 0.8291 - loss: 0.3977 - val_accuracy: 0.8066 - val_loss: 0.4067
# Epoch 15/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 644ms/step - accuracy: 0.8160 - loss: 0.4137 - val_accuracy: 0.8066 - val_loss: 0.4050
# Epoch 16/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 643ms/step - accuracy: 0.8041 - loss: 0.4522 - val_accuracy: 0.8011 - val_loss: 0.4100
# Epoch 17/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 652ms/step - accuracy: 0.7992 - loss: 0.4268 - val_accuracy: 0.8011 - val_loss: 0.4031
# Epoch 18/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 643ms/step - accuracy: 0.8067 - loss: 0.4377 - val_accuracy: 0.8122 - val_loss: 0.3948
# Epoch 19/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 641ms/step - accuracy: 0.8109 - loss: 0.4239 - val_accuracy: 0.7901 - val_loss: 0.4526
# Epoch 20/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 645ms/step - accuracy: 0.8130 - loss: 0.4141 - val_accuracy: 0.8066 - val_loss: 0.4077
# Epoch 21/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 646ms/step - accuracy: 0.8153 - loss: 0.4224 - val_accuracy: 0.7956 - val_loss: 0.4048
# Epoch 22/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 644ms/step - accuracy: 0.8088 - loss: 0.4108 - val_accuracy: 0.8122 - val_loss: 0.4066
# Epoch 23/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 648ms/step - accuracy: 0.8089 - loss: 0.4154 - val_accuracy: 0.7845 - val_loss: 0.4308
# Epoch 24/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 644ms/step - accuracy: 0.8175 - loss: 0.4084 - val_accuracy: 0.8122 - val_loss: 0.3952
# Epoch 25/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 649ms/step - accuracy: 0.8054 - loss: 0.4243 - val_accuracy: 0.8011 - val_loss: 0.3955
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 496ms/step - accuracy: 0.8091 - loss: 0.4143
# Test Loss: 0.4055, Test Accuracy: 0.8011

# %% [markdown]
# # ResNet 50

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks

# Data Preprocessing
train_dataset = tf.keras.utils.image_dataset_from_directory(
    r"C:\Users\rekha\Downloads\glu_data\train",
    image_size=(256, 256),
    batch_size=32,
    label_mode='categorical'
)

val_dataset = tf.keras.utils.image_dataset_from_directory(
    r"C:\Users\rekha\Downloads\glu_data\val",
    image_size=(256, 256),
    batch_size=32,
    label_mode='categorical'
)

# Normalize the data
normalization_layer = layers.Rescaling(1.0 / 255)
train_dataset = train_dataset.map(lambda x, y: (normalization_layer(x), y))
val_dataset = val_dataset.map(lambda x, y: (normalization_layer(x), y))

# Data Augmentation
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.4),
    layers.RandomZoom(0.4),
    layers.RandomContrast(0.3),
    layers.RandomBrightness(0.3),
    layers.RandomTranslation(0.2, 0.2),
    layers.GaussianNoise(0.1)
])
# Uncomment if augmentation is required in training
# train_dataset = train_dataset.map(lambda x, y: (data_augmentation(x, training=True), y))

# Load Pre-trained MobileNetV2


from tensorflow.keras import regularizers

# Adding L2 regularization to the Dense layers
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.5),
    layers.Dense(2, activation='softmax')  # Ensure this matches the number of classes
])



# Compile the Model
model.compile(
    optimizer=optimizers.Adam(learning_rate=0.0001),  # Lower LR for fine-tuning
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Callbacks
reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)
early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the Model
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=25,
    callbacks=[reduce_lr, early_stopping]
)

# Evaluate the Model
test_loss, test_accuracy = model.evaluate(val_dataset)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Found 1455 files belonging to 2 classes.
# Found 181 files belonging to 2 classes.
# Epoch 1/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 36s 676ms/step - accuracy: 0.5344 - loss: 5.0047 - val_accuracy: 0.7182 - val_loss: 4.4097 - learning_rate: 1.0000e-04
# Epoch 2/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 645ms/step - accuracy: 0.6936 - loss: 4.3516 - val_accuracy: 0.7459 - val_loss: 3.9845 - learning_rate: 1.0000e-04
# Epoch 3/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 650ms/step - accuracy: 0.7232 - loss: 3.9142 - val_accuracy: 0.7624 - val_loss: 3.6214 - learning_rate: 1.0000e-04
# Epoch 4/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 651ms/step - accuracy: 0.7698 - loss: 3.5498 - val_accuracy: 0.7845 - val_loss: 3.3017 - learning_rate: 1.0000e-04
# Epoch 5/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 650ms/step - accuracy: 0.7880 - loss: 3.2316 - val_accuracy: 0.8066 - val_loss: 3.0275 - learning_rate: 1.0000e-04
# Epoch 6/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 654ms/step - accuracy: 0.8156 - loss: 2.9477 - val_accuracy: 0.7735 - val_loss: 2.8037 - learning_rate: 1.0000e-04
# Epoch 7/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 32s 655ms/step - accuracy: 0.8351 - loss: 2.6921 - val_accuracy: 0.8066 - val_loss: 2.5842 - learning_rate: 1.0000e-04
# Epoch 8/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 655ms/step - accuracy: 0.8268 - loss: 2.4986 - val_accuracy: 0.8177 - val_loss: 2.4047 - learning_rate: 1.0000e-04
# Epoch 9/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 33s 677ms/step - accuracy: 0.8303 - loss: 2.3288 - val_accuracy: 0.8122 - val_loss: 2.2458 - learning_rate: 1.0000e-04
# Epoch 10/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 32s 660ms/step - accuracy: 0.8425 - loss: 2.1560 - val_accuracy: 0.8066 - val_loss: 2.1164 - learning_rate: 1.0000e-04
# Epoch 11/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 33s 682ms/step - accuracy: 0.8468 - loss: 2.0262 - val_accuracy: 0.8122 - val_loss: 1.9796 - learning_rate: 1.0000e-04
# Epoch 12/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 32s 671ms/step - accuracy: 0.8421 - loss: 1.9074 - val_accuracy: 0.8177 - val_loss: 1.8767 - learning_rate: 1.0000e-04
# Epoch 13/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 34s 699ms/step - accuracy: 0.8548 - loss: 1.7926 - val_accuracy: 0.8122 - val_loss: 1.7769 - learning_rate: 1.0000e-04
# Epoch 14/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 34s 701ms/step - accuracy: 0.8677 - loss: 1.7001 - val_accuracy: 0.8232 - val_loss: 1.7016 - learning_rate: 1.0000e-04
# Epoch 15/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 33s 698ms/step - accuracy: 0.8678 - loss: 1.6097 - val_accuracy: 0.8066 - val_loss: 1.6188 - learning_rate: 1.0000e-04
# Epoch 16/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 32s 660ms/step - accuracy: 0.8627 - loss: 1.5360 - val_accuracy: 0.8177 - val_loss: 1.5500 - learning_rate: 1.0000e-04
# Epoch 17/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 32s 656ms/step - accuracy: 0.8812 - loss: 1.4577 - val_accuracy: 0.8232 - val_loss: 1.4835 - learning_rate: 1.0000e-04
# Epoch 18/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 32s 672ms/step - accuracy: 0.8676 - loss: 1.3992 - val_accuracy: 0.8122 - val_loss: 1.4404 - learning_rate: 1.0000e-04
# Epoch 19/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 39s 821ms/step - accuracy: 0.8698 - loss: 1.3441 - val_accuracy: 0.8122 - val_loss: 1.3875 - learning_rate: 1.0000e-04
# Epoch 20/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 834ms/step - accuracy: 0.8797 - loss: 1.2774 - val_accuracy: 0.8122 - val_loss: 1.3298 - learning_rate: 1.0000e-04
# Epoch 21/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 830ms/step - accuracy: 0.8792 - loss: 1.2385 - val_accuracy: 0.8011 - val_loss: 1.2872 - learning_rate: 1.0000e-04
# Epoch 22/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 42s 873ms/step - accuracy: 0.8842 - loss: 1.1985 - val_accuracy: 0.8177 - val_loss: 1.2560 - learning_rate: 1.0000e-04
# Epoch 23/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 42s 882ms/step - accuracy: 0.8745 - loss: 1.1518 - val_accuracy: 0.8232 - val_loss: 1.2150 - learning_rate: 1.0000e-04
# Epoch 24/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 44s 911ms/step - accuracy: 0.8852 - loss: 1.1185 - val_accuracy: 0.8122 - val_loss: 1.1796 - learning_rate: 1.0000e-04
# Epoch 25/25
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 857ms/step - accuracy: 0.8768 - loss: 1.0896 - val_accuracy: 0.8177 - val_loss: 1.1516 - learning_rate: 1.0000e-04
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 632ms/step - accuracy: 0.8354 - loss: 1.1426
# Test Loss: 1.1515, Test Accuracy: 0.8177

# %% [markdown]
# # CNN

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf

# Load and Normalize Test Data
normalization_layer = tf.keras.layers.Rescaling(1.0 / 255)
val_dataset = tf.keras.utils.image_dataset_from_directory(
    r"C:\Users\rekha\Downloads\split_dataset\val",
    image_size=(256, 256),
    batch_size=32,
    label_mode='categorical'
)
val_dataset = test_dataset.map(lambda x, y: (normalization_layer(x), y))

# Data Augmentation
datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.1,  # Reduced
    zoom_range=0.1,   # Reduced
    horizontal_flip=True
)

# Train Generator
train_generator = datagen.flow_from_directory(
    r"C:\Users\rekha\Downloads\split_dataset\train",
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical'
)

# CNN Model
classifier = Sequential()
classifier.add(Conv2D(32, (3, 3), input_shape=(256, 256, 3), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))
classifier.add(Conv2D(32, (3, 3), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))
classifier.add(Flatten())
classifier.add(Dense(units=512, activation='relu'))
classifier.add(BatchNormalization(momentum=0.8))
classifier.add(Dense(256, activation='relu'))
classifier.add(Dropout(0.2))
classifier.add(Dense(units=2, activation='softmax'))

# Compile Model
classifier.compile(optimizer=Adam(learning_rate=1e-5, clipvalue=1.0), loss='categorical_crossentropy', metrics=['accuracy'])

# Callbacks
reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-7)
early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train Model
classifier.fit(
    train_generator,
    epochs=50,
    validation_data=test_dataset,
    callbacks=[reduce_lr, early_stopping]
)
# Out:
# Found 128 files belonging to 2 classes.
# Found 1032 images belonging to 2 classes.
# C:\Users\rekha\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Epoch 1/50
# C:\Users\rekha\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.6814 - loss: 0.5853 - val_accuracy: 0.7663 - val_loss: 0.4743 - learning_rate: 1.0000e-05
# Epoch 2/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 77s 2s/step - accuracy: 0.7959 - loss: 0.4321 - val_accuracy: 0.6793 - val_loss: 0.5529 - learning_rate: 1.0000e-05
# Epoch 3/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.8389 - loss: 0.3598 - val_accuracy: 0.7120 - val_loss: 0.6036 - learning_rate: 1.0000e-05
# Epoch 4/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.8450 - loss: 0.3429 - val_accuracy: 0.7554 - val_loss: 0.4699 - learning_rate: 1.0000e-05
# Epoch 5/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.8431 - loss: 0.3290 - val_accuracy: 0.7989 - val_loss: 0.4091 - learning_rate: 1.0000e-05
# Epoch 6/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.8605 - loss: 0.2969 - val_accuracy: 0.6739 - val_loss: 0.5609 - learning_rate: 1.0000e-05
# Epoch 7/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.8507 - loss: 0.3163 - val_accuracy: 0.8424 - val_loss: 0.3751 - learning_rate: 1.0000e-05
# Epoch 8/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.9048 - loss: 0.2582 - val_accuracy: 0.6522 - val_loss: 0.7085 - learning_rate: 1.0000e-05
# Epoch 9/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.8666 - loss: 0.2981 - val_accuracy: 0.7989 - val_loss: 0.3728 - learning_rate: 1.0000e-05
# Epoch 10/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.8912 - loss: 0.2590 - val_accuracy: 0.7880 - val_loss: 0.3629 - learning_rate: 1.0000e-05
# Epoch 11/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 59s 2s/step - accuracy: 0.8828 - loss: 0.2892 - val_accuracy: 0.7446 - val_loss: 0.4135 - learning_rate: 1.0000e-05
# Epoch 12/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.8836 - loss: 0.2580 - val_accuracy: 0.8478 - val_loss: 0.3725 - learning_rate: 1.0000e-05
# Epoch 13/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.8889 - loss: 0.2630 - val_accuracy: 0.7120 - val_loss: 0.4761 - learning_rate: 1.0000e-05
# Epoch 14/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9091 - loss: 0.2341 - val_accuracy: 0.7826 - val_loss: 0.3830 - learning_rate: 1.0000e-05
# Epoch 15/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.9251 - loss: 0.2098 - val_accuracy: 0.8315 - val_loss: 0.3424 - learning_rate: 1.0000e-05
# Epoch 16/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.9113 - loss: 0.2302 - val_accuracy: 0.7663 - val_loss: 0.3594 - learning_rate: 1.0000e-05
# Epoch 17/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.9126 - loss: 0.2268 - val_accuracy: 0.8152 - val_loss: 0.3594 - learning_rate: 1.0000e-05
# Epoch 18/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.9184 - loss: 0.2192 - val_accuracy: 0.7717 - val_loss: 0.3731 - learning_rate: 1.0000e-05
# Epoch 19/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 60s 2s/step - accuracy: 0.9318 - loss: 0.2066 - val_accuracy: 0.7391 - val_loss: 0.4877 - learning_rate: 1.0000e-05
# Epoch 20/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - accuracy: 0.9164 - loss: 0.2093 - val_accuracy: 0.7554 - val_loss: 0.3728 - learning_rate: 1.0000e-05
# Epoch 21/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.9224 - loss: 0.2110 - val_accuracy: 0.7717 - val_loss: 0.3691 - learning_rate: 2.0000e-06
# Epoch 22/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.9379 - loss: 0.1928 - val_accuracy: 0.7935 - val_loss: 0.3265 - learning_rate: 2.0000e-06
# Epoch 23/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - accuracy: 0.9397 - loss: 0.1679 - val_accuracy: 0.8261 - val_loss: 0.3131 - learning_rate: 2.0000e-06
# Epoch 24/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.9370 - loss: 0.1780 - val_accuracy: 0.7935 - val_loss: 0.3249 - learning_rate: 2.0000e-06
# Epoch 25/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.9308 - loss: 0.2070 - val_accuracy: 0.8043 - val_loss: 0.3267 - learning_rate: 2.0000e-06
# Epoch 26/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9473 - loss: 0.1621 - val_accuracy: 0.7935 - val_loss: 0.3299 - learning_rate: 2.0000e-06
# Epoch 27/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9305 - loss: 0.1801 - val_accuracy: 0.8261 - val_loss: 0.3019 - learning_rate: 2.0000e-06
# Epoch 28/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9304 - loss: 0.1775 - val_accuracy: 0.8043 - val_loss: 0.3276 - learning_rate: 2.0000e-06
# Epoch 29/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9368 - loss: 0.1740 - val_accuracy: 0.8152 - val_loss: 0.3024 - learning_rate: 2.0000e-06
# Epoch 30/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.9505 - loss: 0.1670 - val_accuracy: 0.8152 - val_loss: 0.3275 - learning_rate: 2.0000e-06
# Epoch 31/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.9624 - loss: 0.1454 - val_accuracy: 0.8424 - val_loss: 0.2932 - learning_rate: 2.0000e-06
# Epoch 32/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.9343 - loss: 0.1639 - val_accuracy: 0.8152 - val_loss: 0.2993 - learning_rate: 2.0000e-06
# Epoch 33/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.9386 - loss: 0.1744 - val_accuracy: 0.8152 - val_loss: 0.3126 - learning_rate: 2.0000e-06
# Epoch 34/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.9373 - loss: 0.2043 - val_accuracy: 0.8098 - val_loss: 0.3077 - learning_rate: 2.0000e-06
# Epoch 35/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.9518 - loss: 0.1466 - val_accuracy: 0.8315 - val_loss: 0.3005 - learning_rate: 2.0000e-06
# Epoch 36/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.9288 - loss: 0.1782 - val_accuracy: 0.8261 - val_loss: 0.3011 - learning_rate: 2.0000e-06
# Epoch 37/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.9279 - loss: 0.1729 - val_accuracy: 0.8370 - val_loss: 0.3043 - learning_rate: 4.0000e-07
# Epoch 38/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.9605 - loss: 0.1422 - val_accuracy: 0.8261 - val_loss: 0.2979 - learning_rate: 4.0000e-07
# Epoch 39/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.9462 - loss: 0.1529 - val_accuracy: 0.8370 - val_loss: 0.3062 - learning_rate: 4.0000e-07
# Epoch 40/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.9555 - loss: 0.1426 - val_accuracy: 0.8261 - val_loss: 0.3025 - learning_rate: 4.0000e-07
# Epoch 41/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9453 - loss: 0.1574 - val_accuracy: 0.8261 - val_loss: 0.3022 - learning_rate: 4.0000e-07

# %%
# Load the Test Dataset
test_dataset = tf.keras.utils.image_dataset_from_directory(
    r"C:\Users\rekha\Downloads\split_dataset\test",  # Replace with your test data path
    image_size=(256, 256),
    batch_size=32,
    label_mode='categorical'
)

# Normalize the Test Data
test_dataset = test_dataset.map(lambda x, y: (normalization_layer(x), y))

# Evaluate the Model on the Test Dataset
test_loss, test_accuracy = classifier.evaluate(test_dataset)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Found 131 files belonging to 2 classes.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - accuracy: 0.9165 - loss: 0.1745
# Test Loss: 0.2025, Test Accuracy: 0.9084

# %%
model.save(r"C:\Users\rekha\Downloads\combineo\glaucoma_90acc.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Load augmented data for training
train_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(
    augmented_train_dir,
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical'
)

# Load validation data from original dataset
val_datagen = ImageDataGenerator(rescale=1./255)
val_generator = val_datagen.flow_from_directory(
    train_dir,  # Use original images for validation
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical'
)

# Train the model
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=10  # Adjust based on performance
)
# Out:
# Found 7760 images belonging to 2 classes.
# Found 1552 images belonging to 2 classes.
# Epoch 1/10
# C:\Users\rekha\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 276s 1s/step - accuracy: 0.6628 - loss: 1.2286 - val_accuracy: 0.7384 - val_loss: 0.5482
# Epoch 2/10
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 205s 843ms/step - accuracy: 0.7608 - loss: 0.5142 - val_accuracy: 0.7610 - val_loss: 0.5202
# Epoch 3/10
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 229s 942ms/step - accuracy: 0.7807 - loss: 0.4730 - val_accuracy: 0.7758 - val_loss: 0.4760
# Epoch 4/10
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 207s 850ms/step - accuracy: 0.8097 - loss: 0.4082 - val_accuracy: 0.7610 - val_loss: 0.4681
# Epoch 5/10
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 200s 822ms/step - accuracy: 0.8234 - loss: 0.3878 - val_accuracy: 0.7745 - val_loss: 0.4619
# Epoch 6/10
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 193s 793ms/step - accuracy: 0.8461 - loss: 0.3473 - val_accuracy: 0.7726 - val_loss: 0.4778
# Epoch 7/10
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 193s 791ms/step - accuracy: 0.8749 - loss: 0.3007 - val_accuracy: 0.7571 - val_loss: 0.5732
# Epoch 8/10
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 724s 954ms/step - accuracy: 0.8844 - loss: 0.2675 - val_accuracy: 0.7726 - val_loss: 0.5141
# Epoch 9/10
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 212s 854ms/step - accuracy: 0.9026 - loss: 0.2325 - val_accuracy: 0.7474 - val_loss: 0.5791
# Epoch 10/10
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 204s 838ms/step - accuracy: 0.9089 - loss: 0.2236 - val_accuracy: 0.7075 - val_loss: 0.7227

# %%
classifier.fit(
    train_generator,
    epochs=20,
    validation_data=val_generator,
    callbacks=[reduce_lr, early_stopping]
)
# Out:
# Epoch 1/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 195s 3s/step - accuracy: 0.8755 - loss: 0.2987 - val_accuracy: 0.7506 - val_loss: 0.4643 - learning_rate: 2.0000e-06
# Epoch 2/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 181s 3s/step - accuracy: 0.8832 - loss: 0.2801 - val_accuracy: 0.7552 - val_loss: 0.4737 - learning_rate: 2.0000e-06
# Epoch 3/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - accuracy: 0.8942 - loss: 0.2688 - val_accuracy: 0.7494 - val_loss: 0.4624 - learning_rate: 2.0000e-06
# Epoch 4/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 187s 3s/step - accuracy: 0.8960 - loss: 0.2656 - val_accuracy: 0.7481 - val_loss: 0.4345 - learning_rate: 2.0000e-06
# Epoch 5/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 220s 3s/step - accuracy: 0.8924 - loss: 0.2726 - val_accuracy: 0.7532 - val_loss: 0.4471 - learning_rate: 2.0000e-06
# Epoch 6/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 177s 3s/step - accuracy: 0.9038 - loss: 0.2584 - val_accuracy: 0.7126 - val_loss: 0.5060 - learning_rate: 2.0000e-06
# Epoch 7/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 180s 3s/step - accuracy: 0.9087 - loss: 0.2533 - val_accuracy: 0.7487 - val_loss: 0.4564 - learning_rate: 2.0000e-06
# Epoch 8/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 235s 4s/step - accuracy: 0.9108 - loss: 0.2489 - val_accuracy: 0.7197 - val_loss: 0.5028 - learning_rate: 2.0000e-06
# Epoch 9/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 228s 4s/step - accuracy: 0.9127 - loss: 0.2436 - val_accuracy: 0.7835 - val_loss: 0.4428 - learning_rate: 2.0000e-06
# Epoch 10/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 213s 3s/step - accuracy: 0.9208 - loss: 0.2361 - val_accuracy: 0.7423 - val_loss: 0.4724 - learning_rate: 4.0000e-07
# Epoch 11/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 202s 3s/step - accuracy: 0.9126 - loss: 0.2361 - val_accuracy: 0.7326 - val_loss: 0.4978 - learning_rate: 4.0000e-07
# Epoch 12/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 187s 3s/step - accuracy: 0.9238 - loss: 0.2341 - val_accuracy: 0.7352 - val_loss: 0.4649 - learning_rate: 4.0000e-07
# Epoch 13/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 205s 3s/step - accuracy: 0.9278 - loss: 0.2273 - val_accuracy: 0.7461 - val_loss: 0.4614 - learning_rate: 4.0000e-07
# Epoch 14/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 250s 4s/step - accuracy: 0.9210 - loss: 0.2323 - val_accuracy: 0.7423 - val_loss: 0.4595 - learning_rate: 4.0000e-07

# %%
classifier.save(r"C:\Users\rekha\Downloads\combinex\combinexxy_cnn.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from tensorflow.keras import callbacks, layers
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# Data Augmentation (Improved)
datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.15,  
    zoom_range=0.15,  
    horizontal_flip=True,
    rotation_range=20,  # New
    width_shift_range=0.1,  # New
    height_shift_range=0.1  # New
)

# Train Generator
train_generator = datagen.flow_from_directory(
    r"C:\Users\rekha\Desktop\split_dataset\train",
    target_size=(256, 256),
    batch_size=64,
    class_mode='categorical'
)

# Validation Data Generator
val_datagen = ImageDataGenerator(rescale=1./255)
val_generator = val_datagen.flow_from_directory(
    r"C:\Users\rekha\Desktop\split_dataset\val",
    target_size=(256, 256),
    batch_size=64,
    class_mode='categorical'
)

# Class Weights for Imbalance Handling
class_labels = train_generator.classes
class_weights = compute_class_weight(class_weight="balanced", classes=np.unique(class_labels), y=class_labels)
class_weight_dict = {i: class_weights[i] for i in range(len(class_weights))}

# Improved CNN Model
classifier = Sequential([
    Conv2D(64, (3, 3), input_shape=(256, 256, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    
    Flatten(),
    Dense(units=512, activation='relu'),
    BatchNormalization(momentum=0.8),
    Dense(256, activation='relu'),
    Dropout(0.3),  # Increased dropout to avoid overfitting
    Dense(units=2, activation='softmax')
])

# Compile Model with Lower Learning Rate
classifier.compile(optimizer=Adam(learning_rate=1e-4, clipvalue=1.0), loss='categorical_crossentropy', metrics=['accuracy'])

# Callbacks
reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=4, min_lr=1e-7)
early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)

# Train Model with Class Weights
classifier.fit(
    train_generator,
    epochs=20,
    validation_data=val_generator,
    class_weight=class_weight_dict,  # Added class weights
    callbacks=[reduce_lr, early_stopping]
)

# Load and Normalize Test Data
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    r"C:\Users\rekha\Desktop\split_dataset\test",
    target_size=(256, 256),
    batch_size=64,
    class_mode='categorical',
    shuffle=False
)

# Evaluate the Model on the Test Dataset
test_loss, test_accuracy = classifier.evaluate(test_generator)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Found 5432 images belonging to 2 classes.
# Found 1552 images belonging to 2 classes.
# C:\Users\rekha\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Epoch 1/20
# C:\Users\rekha\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 772s 9s/step - accuracy: 0.6504 - loss: 0.6932 - val_accuracy: 0.7545 - val_loss: 0.5498 - learning_rate: 1.0000e-04
# Epoch 2/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 576s 6s/step - accuracy: 0.7352 - loss: 0.5521 - val_accuracy: 0.7642 - val_loss: 0.5034 - learning_rate: 1.0000e-04
# Epoch 3/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 702s 8s/step - accuracy: 0.7607 - loss: 0.4975 - val_accuracy: 0.7867 - val_loss: 0.4642 - learning_rate: 1.0000e-04
# Epoch 4/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 589s 7s/step - accuracy: 0.7814 - loss: 0.4681 - val_accuracy: 0.7867 - val_loss: 0.4676 - learning_rate: 1.0000e-04
# Epoch 5/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 546s 6s/step - accuracy: 0.7709 - loss: 0.4856 - val_accuracy: 0.7423 - val_loss: 0.5206 - learning_rate: 1.0000e-04
# Epoch 6/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 571s 7s/step - accuracy: 0.7885 - loss: 0.4537 - val_accuracy: 0.7133 - val_loss: 0.5495 - learning_rate: 1.0000e-04
# Epoch 7/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 494s 6s/step - accuracy: 0.7881 - loss: 0.4579 - val_accuracy: 0.8112 - val_loss: 0.4248 - learning_rate: 1.0000e-04
# Epoch 8/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 605s 7s/step - accuracy: 0.7961 - loss: 0.4353 - val_accuracy: 0.7642 - val_loss: 0.4825 - learning_rate: 1.0000e-04
# Epoch 9/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 554s 6s/step - accuracy: 0.7966 - loss: 0.4429 - val_accuracy: 0.8138 - val_loss: 0.4155 - learning_rate: 1.0000e-04
# Epoch 10/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 601s 7s/step - accuracy: 0.7953 - loss: 0.4373 - val_accuracy: 0.8215 - val_loss: 0.4042 - learning_rate: 1.0000e-04
# Epoch 11/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 552s 6s/step - accuracy: 0.8052 - loss: 0.4221 - val_accuracy: 0.8164 - val_loss: 0.4129 - learning_rate: 1.0000e-04
# Epoch 12/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 517s 6s/step - accuracy: 0.8081 - loss: 0.4133 - val_accuracy: 0.8280 - val_loss: 0.3832 - learning_rate: 1.0000e-04
# Epoch 13/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 495s 6s/step - accuracy: 0.8113 - loss: 0.4005 - val_accuracy: 0.8151 - val_loss: 0.3868 - learning_rate: 1.0000e-04
# Epoch 14/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 475s 5s/step - accuracy: 0.8178 - loss: 0.3948 - val_accuracy: 0.8080 - val_loss: 0.4146 - learning_rate: 1.0000e-04
# Epoch 15/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 510s 6s/step - accuracy: 0.8126 - loss: 0.3906 - val_accuracy: 0.8202 - val_loss: 0.3959 - learning_rate: 1.0000e-04
# Epoch 16/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 428s 5s/step - accuracy: 0.8182 - loss: 0.3909 - val_accuracy: 0.8325 - val_loss: 0.3850 - learning_rate: 1.0000e-04
# Epoch 17/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2017s 24s/step - accuracy: 0.8331 - loss: 0.3785 - val_accuracy: 0.8280 - val_loss: 0.3783 - learning_rate: 2.0000e-05
# Epoch 18/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 439s 5s/step - accuracy: 0.8401 - loss: 0.3586 - val_accuracy: 0.8363 - val_loss: 0.3807 - learning_rate: 2.0000e-05
# Epoch 19/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 464s 5s/step - accuracy: 0.8397 - loss: 0.3541 - val_accuracy: 0.8338 - val_loss: 0.3553 - learning_rate: 2.0000e-05
# Epoch 20/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 534s 6s/step - accuracy: 0.8358 - loss: 0.3530 - val_accuracy: 0.8376 - val_loss: 0.3771 - learning_rate: 2.0000e-05
# Found 776 images belonging to 2 classes.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.7735 - loss: 0.4095
# Test Loss: 0.3768, Test Accuracy: 0.8183

# %%
# Load the Test Dataset
test_dataset = tf.keras.utils.image_dataset_from_directory(
    r"C:\Users\rekha\Downloads\split_dataset\test",  # Replace with your test data path
    image_size=(256, 256),
    batch_size=64,
    label_mode='categorical'
)
normalization_layer = layers.Rescaling(1.0 / 255)
# Normalize the Test Data
test_dataset = test_dataset.map(lambda x, y: (normalization_layer(x), y))

# Evaluate the Model on the Test Dataset
test_loss, test_accuracy =classifier.evaluate(test_dataset)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Found 131 files belonging to 2 classes.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 538ms/step - accuracy: 0.9016 - loss: 0.2472
# Test Loss: 0.2211, Test Accuracy: 0.9008

# %%
model8=load_model(r"C:\Users\rekha\Downloads\combinex\combinexxy_cnn.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Load the Test Dataset
test_dataset = tf.keras.utils.image_dataset_from_directory(
    r"C:\Users\rekha\Downloads\split_dataset\test",  # Replace with your test data path
    image_size=(256, 256),
    batch_size=32,
    label_mode='categorical'
)

# Normalize the Test Data
test_dataset = test_dataset.map(lambda x, y: (normalization_layer(x), y))

# Evaluate the Model on the Test Dataset
test_loss, test_accuracy =model8.evaluate(test_dataset)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Found 131 files belonging to 2 classes.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - accuracy: 0.9829 - loss: 0.0531
# Test Loss: 0.0635, Test Accuracy: 0.9695

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
import numpy as np
from sklearn.metrics import precision_score, recall_score

# Convert lists to numpy arrays (if not already)
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Compute precision and recall
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
# Out:
# Precision: 0.9688
# Recall: 0.9521

# %%
import numpy as np
from sklearn.metrics import classification_report

# Convert to NumPy arrays if needed
y_true = np.array(y_true)  # Ensure it contains true labels
y_pred = np.array(y_pred)  # Ensure it contains predicted labels

# Generate classification report
test_report = classification_report(y_true, y_pred, target_names=['glaucoma', 'normal'], output_dict=True)

# Convert to DataFrame for better visualization
import pandas as pd
test_df = pd.DataFrame(test_report).transpose()

print(test_df)
# Out:
#               precision    recall  f1-score      support
# glaucoma       0.951830  0.968627  0.960155   510.000000
# normal         0.968811  0.952107  0.960386   522.000000
# accuracy       0.960271  0.960271  0.960271     0.960271
# macro avg      0.960321  0.960367  0.960271  1032.000000
# weighted avg   0.960419  0.960271  0.960272  1032.000000

# %%
def glaucoma_prediction(test_image):
  image = img_to_array(test_image)
  image = np.expand_dims(image, axis = 0)
  result = np.argmax(model8.predict(image))
  return result

# %%
test_image = load_img(r"C:\Users\rekha\Downloads\ACRIMA\NOT PARTITIONED\glaucoma\Im685_g_ACRIMA.jpg", target_size = (256,256))
prediction = glaucoma_prediction(test_image)
if prediction == 0:
 print("Glaucoma")
else:
 print("Not Glaucoma")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Glaucoma

# %%
test_image = load_img(r"C:\Users\rekha\Downloads\RIM-ONE_DL_images\partitioned_randomly\test_set\normal\r1_Im169.png", target_size = (256,256))
prediction = glaucoma_prediction(test_image)
if prediction == 0:
 print("Glaucoma")
else:
 print("Not Glaucoma")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Not Glaucoma

# %%
test_image = load_img(r"C:\Users\rekha\Downloads\ACRIMA\PARTITIONED\Testing\normal\Im307_ACRIMA.jpg", target_size = (256,256))
prediction = glaucoma_prediction(test_image)
if prediction == 0:
 print("Glaucoma")
else:
 print("Not Glaucoma")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Not Glaucoma
